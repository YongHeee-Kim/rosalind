# %%
given = '19997 16232 16932 19221 18553 16351'
dominant_p = [1, 1, 1, 0.75, 0.5, 0]

num = list(map(int, given.split()))
ans = sum([i*ii*2 for i, ii in zip(num, dominant_p)])

print(ans)
# Out:
# 153706.5
